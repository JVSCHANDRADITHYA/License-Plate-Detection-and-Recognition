# %%
! yolo detect train data="F:\YOLO_LicensePlate_Dataset\license_plate.yaml" model=yolov8n.pt epochs=50 imgsz=640 batch=16
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\adith\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.154  Python-3.11.13 torch-2.7.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4080 Laptop GPU, 12282MiB)
# ...

# %%
! yolo detect predict model=best.pt source="F:\YOLO_LicensePlate_Dataset\images\val" save_txt save_conf
# Out:
# Ultralytics 8.3.154  Python-3.11.13 torch-2.7.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4080 Laptop GPU, 12282MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/180 F:\YOLO_LicensePlate_Dataset\images\val\103.jpg: 480x640 1 plate, 30.4ms
# image 2/180 F:\YOLO_LicensePlate_Dataset\images\val\12.jpg: 384x640 1 plate, 30.8ms
# image 3/180 F:\YOLO_LicensePlate_Dataset\images\val\121.jpg: 384x640 1 plate, 6.6ms
# image 4/180 F:\YOLO_LicensePlate_Dataset\images\val\126.jpg: 640x480 1 plate, 31.6ms
# image 5/180 F:\YOLO_LicensePlate_Dataset\images\val\127.jpg: 480x640 1 plate, 4.9ms
# image 6/180 F:\YOLO_LicensePlate_Dataset\images\val\129.jpg: 640x480 1 plate, 6.2ms
# image 7/180 F:\YOLO_LicensePlate_Dataset\images\val\134.jpg: 384x640 1 plate, 5.0ms
# image 8/180 F:\YOLO_LicensePlate_Dataset\images\val\139.jpg: 640x480 1 plate, 5.0ms
# image 9/180 F:\YOLO_LicensePlate_Dataset\images\val\143.jpg: 480x640 1 plate, 5.2ms
# ...
